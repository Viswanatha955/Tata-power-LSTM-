# %% [markdown]
# **TATA POWER LSTM**

# %% [markdown]
# Import the libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline 
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %% [markdown]
# Import the data

# %%
data =pd.read_csv("/content/data_extracted (1).csv",parse_dates=['Date'])
data
# Out:
#      Unnamed: 0       Date  OpenPrice_TATApower  HighPrice_TATApower  \
# 0             0 2022-10-07               221.30               222.90
# 1             1 2022-10-06               221.30               223.25
# 2             2 2022-10-04               216.50               219.95
# 3             3 2022-10-03               216.50               218.05
# 4             4 2022-09-30               211.75               217.00
# ..          ...        ...                  ...                  ...
# 986         986 2018-10-15                70.00                71.60
# 987         987 2018-10-12                63.30                72.15
# 988         988 2018-10-11                63.45                63.85
# 989         989 2018-10-10                60.75                65.40
# 990         990 2018-10-09                62.35                62.45
#
#      LowPrice_TATApower  ClosePrice_TATApower  WAP_TATApower  \
# 0                218.85                222.55     220.883364
# ...

# %% [markdown]
# Data understanding

# %%
data.shape
# Out:
# (991, 26)

# %%
data.head(5)
# Out:
#    Unnamed: 0       Date  OpenPrice_TATApower  HighPrice_TATApower  \
# 0           0 2022-10-07               221.30               222.90
# 1           1 2022-10-06               221.30               223.25
# 2           2 2022-10-04               216.50               219.95
# 3           3 2022-10-03               216.50               218.05
# 4           4 2022-09-30               211.75               217.00
#
#    LowPrice_TATApower  ClosePrice_TATApower  WAP_TATApower  NShares_TATApower  \
# 0              218.85                222.55     220.883364            1042282
# 1              220.55                221.70     221.945001             517734
# 2              216.20                219.00     218.105957             526697
# 3              211.95                213.25     215.360304            1317633
# 4              210.20                216.50     213.866107            1503876
#
#    OpenPrice_JSWenergy  HighPrice_JSWenergy  ...  LowPrice_BOROSILre  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0       Date  OpenPrice_TATApower  HighPrice_TATApower  \
# 986         986 2018-10-15                70.00                71.60
# 987         987 2018-10-12                63.30                72.15
# 988         988 2018-10-11                63.45                63.85
# 989         989 2018-10-10                60.75                65.40
# 990         990 2018-10-09                62.35                62.45
#
#      LowPrice_TATApower  ClosePrice_TATApower  WAP_TATApower  \
# 986               68.90                 71.30      70.747601
# 987               63.00                 68.85      67.301043
# 988               61.65                 62.35      62.742027
# 989               60.75                 65.00      63.214573
# 990               59.90                 61.05      61.313782
#
#      NShares_TATApower  OpenPrice_JSWenergy  HighPrice_JSWenergy  ...  \
# 986             676837                64.00                 64.5  ...
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  OpenPrice_TATApower  HighPrice_TATApower  \
# count   991.00000           991.000000           991.000000
# mean    495.00000           112.644803           114.524773
# std     286.22136            72.981094            74.185337
# min       0.00000            27.450000            28.600000
# 25%     247.50000            58.325000            59.275000
# 50%     495.00000            75.100000            76.200000
# 75%     742.50000           179.925000           184.400000
# max     990.00000           293.000000           298.000000
#
#        LowPrice_TATApower  ClosePrice_TATApower  WAP_TATApower  \
# count          991.000000            991.000000     991.000000
# mean           110.356559            112.350706     112.463936
# std             71.574216             72.827036      72.908454
# min             27.000000             27.350000      28.017132
# 25%             57.100000             57.975000      58.090514
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                991 non-null    int64
#  1   Date                      991 non-null    datetime64[ns]
#  2   OpenPrice_TATApower       991 non-null    float64
#  3   HighPrice_TATApower       991 non-null    float64
#  4   LowPrice_TATApower        991 non-null    float64
#  5   ClosePrice_TATApower      991 non-null    float64
#  6   WAP_TATApower             991 non-null    float64
#  7   NShares_TATApower         991 non-null    int64
#  8   OpenPrice_JSWenergy       991 non-null    float64
#  9   HighPrice_JSWenergy       991 non-null    float64
#  10  LowPrice_JSWenergy        991 non-null    float64
#  11  ClosePrice_JSWenergy      991 non-null    float64
#  12  WAP_JSWenergy             991 non-null    float64
# ...

# %%
data1=data [[ 'Date','OpenPrice_TATApower','HighPrice_TATApower','LowPrice_TATApower','ClosePrice_TATApower','WAP_TATApower','NShares_TATApower']]
data1
# Out:
#           Date  OpenPrice_TATApower  HighPrice_TATApower  LowPrice_TATApower  \
# 0   2022-10-07               221.30               222.90              218.85
# 1   2022-10-06               221.30               223.25              220.55
# 2   2022-10-04               216.50               219.95              216.20
# 3   2022-10-03               216.50               218.05              211.95
# 4   2022-09-30               211.75               217.00              210.20
# ..         ...                  ...                  ...                 ...
# 986 2018-10-15                70.00                71.60               68.90
# 987 2018-10-12                63.30                72.15               63.00
# 988 2018-10-11                63.45                63.85               61.65
# 989 2018-10-10                60.75                65.40               60.75
# 990 2018-10-09                62.35                62.45               59.90
#
# ...

# %%
data1.plot('Date','ClosePrice_TATApower',figsize=(10,4))
plt.show()

# %%
#Heatmap 
plt.figure(figsize=(7,5))
sns.heatmap(data1.corr(),cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# From the above heatmap, you can see a large number of 1s and values close to 1. This means those variables show high positive correlations and are interrelated. This might be possible because of the comparatively very small difference between those values. However, in-stock market this small value is what makes the difference. So, what we are going to do, is add new variables to our dataset that represents the difference between those values.

# %%
data1['OpenPrice_TATApower-HighPrice_TATApower'] = data1['OpenPrice_TATApower']-data1['HighPrice_TATApower']
data1['OpenPrice_TATApower-LowPrice_TATApower'] = data1['OpenPrice_TATApower'] - data1['LowPrice_TATApower']
data1['ClosePrice_TATApower-HighPrice_TATApower'] = data1['ClosePrice_TATApower']-data1['HighPrice_TATApower']
data1['ClosePrice_TATApower-LowPrice_TATApower'] = data1['ClosePrice_TATApower'] - data1['LowPrice_TATApower']
data1['HighPrice_TATApower-LowPrice_TATApower'] = data1['HighPrice_TATApower'] - data1['LowPrice_TATApower']
data1['OpenPrice_TATApower-ClosePrice_TATApower'] = data1['OpenPrice_TATApower'] - data1['ClosePrice_TATApower']
data1.head()
# Out:
#         Date  OpenPrice_TATApower  HighPrice_TATApower  LowPrice_TATApower  \
# 0 2022-10-07               221.30               222.90              218.85
# 1 2022-10-06               221.30               223.25              220.55
# 2 2022-10-04               216.50               219.95              216.20
# 3 2022-10-03               216.50               218.05              211.95
# 4 2022-09-30               211.75               217.00              210.20
#
#    ClosePrice_TATApower  WAP_TATApower  NShares_TATApower  \
# 0                222.55     220.883364            1042282
# 1                221.70     221.945001             517734
# 2                219.00     218.105957             526697
# 3                213.25     215.360304            1317633
# 4                216.50     213.866107            1503876
#
#    OpenPrice_TATApower-HighPrice_TATApower  \
# 0                                    -1.60
# 1                                    -1.95
# ...

# %% [markdown]
# From the previous heatmap, we could realize that those values aren’t very useful. So for more clarity, we will drop those values and take only the new values for creating the heatmap.

# %%
#Heatmap
data2 = data1.copy()
data2 = data2.drop(['OpenPrice_TATApower','HighPrice_TATApower','LowPrice_TATApower','ClosePrice_TATApower',],axis=1)
plt.figure(figsize=(7,5))
sns.heatmap(data2.corr(),cmap='Blues',annot=True)
plt.show()

# %%
sns.barplot(data=data1, x = "OpenPrice_TATApower-HighPrice_TATApower", y="WAP_TATApower")
plt.show()

# %%
sns.barplot(data=data1, x = "HighPrice_TATApower-LowPrice_TATApower", y="WAP_TATApower")

# %% [markdown]
# Moving Average - MA' A moving average (MA) is a widely used indicator in technical analysis that helps smooth out price action by filtering out the “noise” from random price fluctuations. It is a trend-following, or lagging, indicator because it is based on past prices.

# %%
# Let's go ahead and plot out several moving averages
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    data1[column_name]=pd.DataFrame.rolling(data1['ClosePrice_TATApower'],ma).mean()

# %%
data1[['ClosePrice_TATApower','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots=False,figsize=(12,6))
plt.show()

# %%
data1=data.reset_index()['ClosePrice_TATApower']
data1
# Out:
# 0      222.55
# 1      221.70
# 2      219.00
# 3      213.25
# 4      216.50
#         ...
# 986     71.30
# 987     68.85
# 988     62.35
# 989     65.00
# 990     61.05
# Name: ClosePrice_TATApower, Length: 991, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
data1=scaler.fit_transform(np.array(data1).reshape(-1,1))

# %%
print(data1)
# Out:
# [[0.74376072]
#  [0.740522  ]
#  [0.73023433]
#  [0.7083254 ]
#  [0.72070871]
#  [0.70451515]
#  [0.71061155]
#  [0.72432844]
#  [0.71708897]
#  [0.75157173]
#  [0.77843399]
#  [0.77671938]
#  [0.79176986]
#  [0.78072014]
#  [0.79767575]
#  [0.83025338]
#  [0.81577443]
#  [0.81405982]
#  [0.82072776]
#  [0.81920366]
#  [0.82891979]
#  [0.83673081]
#  [0.83825491]
#  [0.79653267]
#  [0.79119832]
#  [0.79919985]
#  [0.7984378 ]
#  [0.78243475]
#  [0.79157935]
#  [0.76909888]
#  [0.77024195]
#  [0.77786245]
#  [0.75004763]
#  [0.78243475]
#  [0.80262907]
#  [0.79958087]
#  [0.79500857]
#  [0.78129167]
#  [0.77005144]
#  [0.76624119]
#  [0.76566965]
#  [0.7801486 ]
#  [0.7633835 ]
#  [0.78148219]
#  [0.78205372]
#  [0.77348066]
#  [0.74128405]
#  [0.72699562]
#  [0.72623357]
#  [0.75747761]
#  [0.7816727 ]
#  [0.77538579]
#  [0.77214708]
#  [0.76224043]
#  [0.76509811]
#  [0.76376453]
#  [0.75328634]
#  [0.73880739]
#  [0.73728329]
#  [0.73956944]
#  [0.73709278]
#  [0.73423509]
# ...

# %%
##splitting dataset into train and test split
training_size=int(len(data1)*0.65)
test_size=len(data1)-training_size
train_data,test_data=data1[0:training_size,:],data1[training_size:len(data1),:1]

# %%
training_size,test_size
# Out:
# (644, 347)

# %%
train_data
# Out:
# array([[0.74376072],
#        [0.740522  ],
#        [0.73023433],
#        [0.7083254 ],
#        [0.72070871],
#        [0.70451515],
#        [0.71061155],
#        [0.72432844],
#        [0.71708897],
#        [0.75157173],
#        [0.77843399],
#        [0.77671938],
#        [0.79176986],
#        [0.78072014],
#        [0.79767575],
#        [0.83025338],
#        [0.81577443],
#        [0.81405982],
#        [0.82072776],
#        [0.81920366],
#        [0.82891979],
#        [0.83673081],
#        [0.83825491],
#        [0.79653267],
#        [0.79119832],
#        [0.79919985],
#        [0.7984378 ],
#        [0.78243475],
#        [0.79157935],
#        [0.76909888],
#        [0.77024195],
#        [0.77786245],
#        [0.75004763],
#        [0.78243475],
#        [0.80262907],
#        [0.79958087],
#        [0.79500857],
#        [0.78129167],
#        [0.77005144],
#        [0.76624119],
#        [0.76566965],
#        [0.7801486 ],
#        [0.7633835 ],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (543, 100)
# (543,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (246, 100)
# (246,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=150,batch_size=64,verbose=1)
# Out:
# Epoch 1/150
# 9/9 [==============================] - 10s 461ms/step - loss: 0.0571 - val_loss: 0.0028
# Epoch 2/150
# 9/9 [==============================] - 2s 210ms/step - loss: 0.0159 - val_loss: 5.4897e-04
# Epoch 3/150
# 9/9 [==============================] - 2s 186ms/step - loss: 0.0060 - val_loss: 2.9626e-04
# Epoch 4/150
# 9/9 [==============================] - 2s 218ms/step - loss: 0.0042 - val_loss: 8.1531e-04
# Epoch 5/150
# 9/9 [==============================] - 2s 202ms/step - loss: 0.0035 - val_loss: 0.0015
# Epoch 6/150
# 9/9 [==============================] - 2s 210ms/step - loss: 0.0030 - val_loss: 5.8309e-04
# Epoch 7/150
# 9/9 [==============================] - 2s 212ms/step - loss: 0.0027 - val_loss: 6.2459e-04
# Epoch 8/150
# 9/9 [==============================] - 2s 209ms/step - loss: 0.0025 - val_loss: 3.1618e-04
# Epoch 9/150
# 9/9 [==============================] - 2s 208ms/step - loss: 0.0025 - val_loss: 6.6168e-04
# Epoch 10/150
# ...

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 8/8 [==============================] - 0s 35ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 142.0174889611516

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 66.7245811713648

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(data1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(data1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(data1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(data1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 347

# %%
x_input=test_data[237:].reshape(1,-1)
x_input.shape
# Out:
# (1, 110)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.15126690798247283,
#  0.14478948371118305,
#  0.1453610211468851,
#  0.14840922080396263,
#  0.1497428081539341,
#  0.15145742046104016,
#  0.1526004953324443,
#  0.14802819584682797,
#  0.1466946084968565,
#  0.14497999618975044,
#  0.15964945703943606,
#  0.1533625452467136,
#  0.14402743379691368,
#  0.14859973328252996,
#  0.14612307106115452,
#  0.15736330729662795,
#  0.16041150695370543,
#  0.16326919413221563,
#  0.16193560678224417,
#  0.16441226900361972,
#  0.1680320060963993,
#  0.16746046866069725,
#  0.15507715755381973,
#  0.16631739378929317,
#  0.1655553438750238,
#  0.1775576300247666,
#  0.1800342922461421,
#  0.18251095446751758,
#  0.18651171651743187,
#  0.18517812916746046,
#  0.1853686416460278,
#  0.1853686416460278,
#  0.18632120403886454,
#  0.18136787959611356,
#  0.17831967993903602,
#  0.18155839207468089,
#  0.18079634216041146,
#  0.178891217374738,
#  0.1809868546389788,
#  0.1804153172032768,
#  0.18212992951038293,
#  0.17831967993903602,
# ...

# %%
# demonstrate prediction for next 30 days
from numpy import array

lst_output=[]
n_steps=110
i=0
while(i<60):
    
    if(len(temp_input)>110):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.14532398]
# 111
# 1 day input [0.17679558 0.17393789 0.17660507 0.17527148 0.16898457 0.16193561
#  0.16460278 0.16746047 0.15869689 0.15126691 0.14478948 0.14536102
#  0.14840922 0.14974281 0.15145742 0.1526005  0.1480282  0.14669461
#  0.14498    0.15964946 0.15336255 0.14402743 0.14859973 0.14612307
#  0.15736331 0.16041151 0.16326919 0.16193561 0.16441227 0.16803201
#  0.16746047 0.15507716 0.16631739 0.16555534 0.17755763 0.18003429
#  0.18251095 0.18651172 0.18517813 0.18536864 0.18536864 0.1863212
#  0.18136788 0.17831968 0.18155839 0.18079634 0.17889122 0.18098685
#  0.18041532 0.18212993 0.17831968 0.18098685 0.18860735 0.18822633
#  0.18975043 0.18917889 0.18517813 0.18822633 0.18727377 0.20099066
#  0.198514   0.19565632 0.19222709 0.19813298 0.19508478 0.19679939
#  0.19679939 0.1908935  0.19794247 0.19737093 0.20213374 0.20556296
#  0.21013526 0.1863212  0.18193942 0.17908173 0.18365403 0.18384454
#  0.18117737 0.19203658 0.19317965 0.1893694  0.1878453  0.18765479
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,161)

# %%
import matplotlib.pyplot as plt

# %%
len(data1)
# Out:
# 991

# %%
plt.plot(day_new,scaler.inverse_transform(data1[891:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=data1.tolist()
df3.extend(lst_output)
plt.plot(df3[800:])

# %%
df3=scaler.inverse_transform(df3).tolist()

# %%
plt.plot(df3)
